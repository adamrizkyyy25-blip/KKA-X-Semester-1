# %% [markdown]
# <a href="https://colab.research.google.com/github/adamrizkyyy25-blip/KKA-X-Semester-1/blob/main/2_Variabel_AdamDNR_X5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Adam Dwi Nur Rizky
#
# Kelas: X.5
#
# No.absen: 01

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("adamjuga46@gmail.com")
print("adamjuga46@gmail.com")
print("adamjuga46@gmail.com")
# Out:
# adamjuga46@gmail.com
# adamjuga46@gmail.com
# adamjuga46@gmail.com

# %%
email_user_1 = "adamjuga46@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# adamjuga46@gmail.com
# adamjuga46@gmail.com
# adamjuga46@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
email user 2 = "adamdwi@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-3837405249.py", line 1
#     email user 2 = "adamdwi@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Hanya Boleh Menggunakan Angka, Huruf dan Underscore

emailuser2 = "adamdwi@gmail.com"

print(emailuser2)
# Out:
# adamdwi@gmail.com

# %%
email_user_2 = "adamrizkyy@gmail.com"

print(email_user_2)
# Out:
# adamrizkyy@gmail.com

# %%
3_email_user = "madaiwd@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-2952660937.py", line 1
#     3_email_user = "madaiwd@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak Boleh Diawali Oleh Angka
email_user_3 = "madaiwd@gmail.com"

print(email_user_3)
# Out:
# madaiwd@gmail.com

# %%
Email_user_4 = "freefire@gmail.com"

print(email_user_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-811127857.py in <cell line: 0>()
#       1 Email_user_4 = "freefire@gmail.com"
#       2
# ----> 3 print(email_user_4)
#
# NameError: name 'email_user_4' is not defined

# %%
#Penulisan Variabel Sensitif Terhadap Kapital

Email_user_4 = "freefire@gmail.com"

print(Email_user_4)
# Out:
# freefire@gmail.com

# %%
if = "mobillegend@gmail.com"

print(if)
# Out:
#   File "/tmp/ipython-input-46163153.py", line 1
#     if = "mobillegend@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
If = "mobillegend@gmail.com"

print(If)
# Out:
# mobillegend@gmail.com

# %%
print = "lionelmessi@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2600647256.py in <cell line: 0>()
#       1 print = "lionelmessi@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "lionelmessi@gmail.com"

print(Print)
# Out:
# lionelmessi@gmail.com

# %%
#Harus deskriptif meski tidak Error
_ = "cronaldo@gmail.com"

print(_)
# Out:
# cronaldo@gmail.com

# %%
_ = "neymarjr@gmail.com"

print(_)
# Out:
# neymarjr@gmail.com

# %%
print(_)
# Out:
# neymarjr@gmail.com

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# #Assignment

# %% [markdown]
# #Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %%
nama = "Andi"
print(nama)
# Out:
# Andi

# %% [markdown]
# #Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %%
nama, umur, kelas = "Budi", "15", "9A"
print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %% [markdown]
# #Chain Assignment

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %%
berat_andi = berat_siti = berat_eko = 45.5

print(berat_andi,berat_siti,berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #Aritmatika

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Jenis-jenis operator aritmatika pada python

# %%
#Penjumlahan
iphone_rolan = 21
iphone_gibran = 4

total_iphone = iphone_rolan + iphone_gibran

print(total_iphone)
# Out:
# 25

# %%
#Pengurangan
iphone_rolan = 21
iphone_gibran = 4

selisih_iphone = iphone_rolan - iphone_gibran

print(selisih_iphone)
# Out:
# 17

# %%
#Perkalian
jumlah_dus = 5
jumlah_botol_per_dus = 10

total_botol = jumlah_dus * jumlah_botol_per_dus

print(total_botol)
# Out:
# 50

# %%
#Pembagian
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan / iphone_gibran

print(pembagian_iphone)
# Out:
# 5.25

# %%
#Pembagian Bulat
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan // iphone_gibran

print(pembagian_iphone)
# Out:
# 5

# %%
#sisa bagi
iphone_rolan = 21
jumlah_anak_yatim = 5

sisa_bagi_iphone = iphone_rolan % jumlah_anak_yatim

print(sisa_bagi_iphone)
# Out:
# 1

# %%
#Perpangkatan
sisi = 5

luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 25

# %%
sisi = 2
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# 8

# %%
luas_persegi = 25

sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# 5.0

# %%
volume_kubus = 8
sisi = volume_kubus ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# #Jenis Tipe Variabel pada Phyton

# %%
#Float
x = 17.5
print(x)
type(x)
# Out:
# 17.5
# float

# %%
#Integer
y = 8
print(y)
type(y)
# Out:
# 8
# int

# %%
#String
z = "shinta"
print(z)
type(z)
# Out:
# shinta
# str

# %%
#Boolean
p = True
print(p)
type(p)
# Out:
# True
# bool

# %%
r = -2.5
print(r)
type(r)
# Out:
# -2.5
# float

# %%
s = 5.1
print(s)
type(s)
# Out:
# 5.1
# float

# %%
k = '&k7akh3.'
print(k)
type(k)
# Out:
# &k7akh3.
# str

# %% [markdown]
# #Mengubah Tipe Data

# %%
a = 25
print(a)
type(a)
# Out:
# 25
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = True
print(b)
type(b)
# Out:
# True
# bool

# %%
b = int(b)
print(b)
type(b)
# Out:
# 1
# int

# %%
b = float(b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b = str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c = False
print(c)
type(c)
# Out:
# False
# bool

# %%
c = float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c = int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c = str(c)
print(c)
type(c)
# Out:
# 0
# str

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>0)
# Out:
# True

# %%
print(7>9)
# Out:
# False

# %%
print(8<9)
# Out:
# True

# %%
print(8<4)
# Out:
# False

# %%
print(5>=5)
# Out:
# True

# %%
print(6>=5)
# Out:
# True

# %%
print(3 == 2)
# Out:
# False

# %%
print(3 == 3)
# Out:
# True

# %%
print(5 != 5)
# Out:
# False

# %%
a = 8
b = 9
print(b<a)
# Out:
# False

# %%
print(b<8)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(7!=8 and 8>2)
# Out:
# True

# %%
print(7==8 and 8>2)
# Out:
# False

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(not 7==8)
# Out:
# True

# %%
m = 10
n = 20
p = 30

print(m<n and p>m)
# Out:
# True

# %%
print(not (m<n or p>m))
# Out:
# False
