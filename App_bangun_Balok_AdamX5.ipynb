# %% [markdown]
# <a href="https://colab.research.google.com/github/adamrizkyyy25-blip/KKA-X-Semester-1/blob/main/App_bangun_Balok_AdamX5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Kelompok: Kutu lompat
#
# Nama panjang: Adam Dwi Nur Rizky
#
# Kelas: X5
#
# No.absen: 01

# %% [markdown]
# # App bangun Balok

# %%
#Program menghitung Volume Balok

#Menerima input dari pengguna
Panjang = int(input("Masukkan Panjang Balok (cm): "))
Lebar = int(input("Masukkan Lebar Balok (cm): "))
Tinggi = int(input("Masukkan Tinggi Balok (cm): "))

#Menghitung Volume
Volume = Panjang * Lebar * Tinggi

#Menampilkan hasil
print(f"Volume Balok adalah: {Volume} cm^3. ")
# Out:
# Masukkan Panjang Balok (cm): 7
# Masukkan Lebar Balok (cm): 6
# Masukkan Tinggi Balok (cm): 5
# Volume Balok adalah: 210 cm^3.
